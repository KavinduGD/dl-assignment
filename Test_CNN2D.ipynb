# %%
import IPython.display as ipd
import librosa
import librosa.display
import pandas as pd
import numpy as np
import tensorflow as tf
import joblib
# Out:
# WARNING:tensorflow:From C:\Users\kavin\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
model = tf.keras.models.load_model('./best-model/your_model.h5')
scaler = joblib.load('./best-model/standard_scaler-1.pkl')
# Out:
# WARNING:tensorflow:From C:\Users\kavin\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\kavin\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# C:\Users\kavin\anaconda3\Lib\site-packages\sklearn\base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 1.4.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
classes=['air_conditioner', 'car_horn', 'children_playing', 'dog_bark', 'drilling', 'engine_idling', 'gun_shot', 'jackhammer', 'siren', 'street_music']

# %%
def extract_features(file_path):
    X, sample_rate = librosa.load(audio_path)
    mels = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T, axis=0)
    return mels

# %%
def predict(file_path, classes):
    # Extract features from the file
    mels = extract_features(file_path)
    
    mels = scaler.transform(mels.reshape(1,-1))
    
    # Reshape features to the required input shape for the model
    mels = mels.reshape(1, 16, 8, 1)
    
    # Get the prediction from the model
    prediction = model.predict(mels)
    
    # Get the index of the maximum value from the prediction
    predicted_index = np.argmax(prediction, axis=1)[0]
    
    # Return the class name with the predicted index
    return classes[predicted_index]

# %% [markdown]
# ## Siren

# %%
audio_path='./sounds/22601-8-0-51.wav'
ipd.Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class_name = predict(audio_path, classes)
print("Predicted class:", class_name)
# Out:
# 1/1 [==============================] - 0s 316ms/step
# Predicted class: siren

# %% [markdown]
# ## engine_idling

# %%
audio_path='./sounds/17853-5-0-10.wav'
ipd.Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class_name = predict(audio_path, classes)
print("Predicted class:", class_name)
# Out:
# 1/1 [==============================] - 0s 70ms/step
# Predicted class: engine_idling

# %% [markdown]
# ## Siren

# %%
audio_path='./sounds/22601-8-0-9.wav'
ipd.Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class_name = predict(audio_path, classes)
print("Predicted class:", class_name)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# Predicted class: siren

# %% [markdown]
# ## Drilling

# %%
audio_path='./sounds/29721-4-0-11.wav'
ipd.Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class_name = predict(audio_path, classes)
print("Predicted class:", class_name)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# Predicted class: drilling

# %% [markdown]
# ## children_playing

# %%
audio_path='./sounds/9223-2-0-17.wav'
ipd.Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class_name = predict(audio_path, classes)
print("Predicted class:", class_name)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# Predicted class: children_playing

# %% [markdown]
# ## Bark

# %%
audio_path='./sounds/344-3-4-0.wav'
ipd.Audio(filename=audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class_name = predict(audio_path, classes)
print("Predicted class:", class_name)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Predicted class: dog_bark
